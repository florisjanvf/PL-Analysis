# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(filepath_or_buffer='data/2018-2019/players.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   full_name                       570 non-null    object
#  1   age                             570 non-null    int64
#  2   birthday                        570 non-null    int64
#  3   birthday_GMT                    570 non-null    object
#  4   league                          570 non-null    object
#  5   season                          570 non-null    object
#  6   position                        570 non-null    object
#  7   Current Club                    570 non-null    object
#  8   minutes_played_overall          570 non-null    int64
#  9   minutes_played_home             570 non-null    int64
#  10  minutes_played_away             570 non-null    int64
#  11  nationality                     570 non-null    object
# ...

# %%
data.head(7)
# Out:
#            full_name  age   birthday birthday_GMT          league     season  \
# 0    Aaron Cresswell   32  629712000   1989/12/15  Premier League  2018/2019
# 1       Aaron Lennon   35  545554800   1987/04/16  Premier League  2018/2019
# 2         Aaron Mooy   31  653382000   1990/09/15  Premier League  2018/2019
# 3       Aaron Ramsey   31  662198400   1990/12/26  Premier League  2018/2019
# 4         Aaron Rowe   22  968310000   2000/09/07  Premier League  2018/2019
# 5  Aaron Wan-Bissaka   24  880531200   1997/11/26  Premier League  2018/2019
# 6  Abdelhamid Sabiri   25  849168000   1996/11/28  Premier League  2018/2019
#
#      position       Current Club  minutes_played_overall  minutes_played_home  \
# 0    Defender    West Ham United                    1589                  888
# 1  Midfielder            Burnley                    1217                  487
# 2  Midfielder  Huddersfield Town                    2327                 1190
# ...

# %%
# check whether this dataframe contains any missing values
data.isna().any().any()
# Out:
# False

# %%
data['age'].describe()
# Out:
# count    570.000000
# mean      29.610526
# std        4.385937
# min       20.000000
# 25%       26.000000
# 50%       30.000000
# 75%       33.000000
# max       43.000000
# Name: age, dtype: float64

# %%
data.sort_values(by='age', ascending=False)
# Out:
#                    full_name  age    birthday birthday_GMT          league  \
# 305           Julián Speroni   43   295858800   1979/05/18  Premier League
# 62               Artur Boruc   42   319881600   1980/02/20  Premier League
# 89         Bruno Saltor Grau   41   339231600   1980/10/01  Premier League
# 224  Heurelho da Silva Gomes   41   351072000   1981/02/15  Premier League
# 445             Peter Crouch   41   349689600   1981/01/30  Premier League
# ..                       ...  ...         ...          ...             ...
# 313             Kayne Ramsey   21   971161200   2000/10/10  Premier League
# 91        Callum Hudson-Odoi   21   973584000   2000/11/07  Premier League
# 392               Matty Daly   21   984211200   2001/03/10  Premier League
# 125             Curtis Jones   21   980841600   2001/01/30  Premier League
# 378          Mason Greenwood   20  1001919600   2001/10/01  Premier League
#
# ...

# %%
data.sort_values(by='age', ascending=True)
# Out:
#                    full_name  age    birthday birthday_GMT          league  \
# 378          Mason Greenwood   20  1001919600   2001/10/01  Premier League
# 313             Kayne Ramsey   21   971161200   2000/10/10  Premier League
# 241             James Garner   21   984470400   2001/03/13  Premier League
# 91        Callum Hudson-Odoi   21   973584000   2000/11/07  Premier League
# 125             Curtis Jones   21   980841600   2001/01/30  Premier League
# ..                       ...  ...         ...          ...             ...
# 445             Peter Crouch   41   349689600   1981/01/30  Premier League
# 89         Bruno Saltor Grau   41   339231600   1980/10/01  Premier League
# 224  Heurelho da Silva Gomes   41   351072000   1981/02/15  Premier League
# 62               Artur Boruc   42   319881600   1980/02/20  Premier League
# 305           Julián Speroni   43   295858800   1979/05/18  Premier League
#
# ...

# %%
data.sort_values(by='goals_overall', ascending=False)
# Out:
#                      full_name  age   birthday birthday_GMT          league  \
# 487                 Sadio Mané   30  702889200   1992/04/10  Premier League
# 453  Pierre-Emerick Aubameyang   33  614156400   1989/06/18  Premier League
# 409              Mohamed Salah   30  708591600   1992/06/15  Premier League
# 502              Sergio Aguero   34  581238000   1988/06/02  Premier League
# 250                Jamie Vardy   35  537350400   1987/01/11  Premier League
# ..                         ...  ...        ...          ...             ...
# 240            Jamal Lascelles   28  753004800   1993/11/11  Premier League
# 239            Jaïro Riedewald   26  842252400   1996/09/09  Premier League
# 238               Jacob Murphy   27  793612800   1995/02/24  Premier League
# 237              Jack Wilshere   30  694252800   1992/01/01  Premier League
# 569           Łukasz Fabiański   37  482659200   1985/04/18  Premier League
#
# ...

# %%
data.sort_values(by='penalty_misses', ascending=False)
# Out:
#                           full_name  age   birthday birthday_GMT  \
# 212                Gylfi Sigurdsson   33  621241200   1989/09/08
# 441                      Paul Pogba   29  732182400   1993/03/15
# 95                    Callum Wilson   30  699177600   1992/02/27
# 353                Luka Milivojević   31  671011200   1991/04/07
# 273                       Joe Ralls   28  750495600   1993/10/13
# ..                              ...  ...        ...          ...
# 184  Fabricio Martín Agosto Ramírez   34  567936000   1987/12/31
# 183                         Fabinho   28  751359600   1993/10/23
# 182                    Fabian Schär   30  693216000   1991/12/20
# 181                    Fabian Delph   32  627638400   1989/11/21
# 569                Łukasz Fabiański   37  482659200   1985/04/18
#
#              league     season    position       Current Club  \
# 212  Premier League  2018/2019  Midfielder            Everton
# ...

# %%
data.sort_values(by='clean_sheets_overall', ascending=False)
# Out:
#                       full_name  age   birthday birthday_GMT          league  \
# 551             Virgil van Dijk   31  678956400   1991/07/08  Premier League
# 409               Mohamed Salah   30  708591600   1992/06/15  Premier League
# 205         Georginio Wijnaldum   31  658310400   1990/11/11  Premier League
# 36               Alisson Becker   29  718009200   1992/10/02  Premier League
# 45             Andrew Robertson   28  763372800   1994/03/11  Premier League
# ..                          ...  ...        ...          ...             ...
# 202                 Gary Madine   32  651481200   1990/08/24  Premier League
# 198  Frederico Rodrigues Santos   29  731318400   1993/03/05  Premier League
# 197             Freddie Woodman   25  857462400   1997/03/04  Premier League
# 196              Fraser Forster   34  574588800   1988/03/17  Premier League
# 171             Emerson Hyndman   26  829033200   1996/04/09  Premier League
#
# ...

# %%
keeper_filter = (data['position'] == 'Goalkeeper')

# %%
goalkeepers_clean_sheets = data.loc[keeper_filter].sort_values(by='clean_sheets_overall', ascending=False)[['full_name', 'age', 'Current Club', 'appearances_overall', 'clean_sheets_overall']]

# %%
goalkeepers_clean_sheets
# Out:
#                           full_name  age             Current Club  \
# 36                   Alisson Becker   29                Liverpool
# 168                         Ederson   29          Manchester City
# 290                 Jordan Pickford   28                  Everton
# 319               Kepa Arrizabalaga   27                  Chelsea
# 225                     Hugo Lloris   35        Tottenham Hotspur
# 375                 Martin Dúbravka   33         Newcastle United
# 312               Kasper Schmeichel   35           Leicester City
# 425     Neil Leonard Dula Etheridge   32             Cardiff City
# 478   Rui Pedro dos Santos Patrício   34  Wolverhampton Wanderers
# 84                       Bernd Leno   30                  Arsenal
# 145                    David de Gea   31        Manchester United
# 569                Łukasz Fabiański   37          West Ham United
# 542                  Vicente Guaita   35           Crystal Palace
# ...

# %%
goalkeepers_clean_sheets['clean_sheets_percentage'] = (goalkeepers_clean_sheets['clean_sheets_overall'] / goalkeepers_clean_sheets['appearances_overall'])

# %%
goalkeepers_clean_sheets
# Out:
#                           full_name  age             Current Club  \
# 36                   Alisson Becker   29                Liverpool
# 168                         Ederson   29          Manchester City
# 290                 Jordan Pickford   28                  Everton
# 319               Kepa Arrizabalaga   27                  Chelsea
# 225                     Hugo Lloris   35        Tottenham Hotspur
# 375                 Martin Dúbravka   33         Newcastle United
# 312               Kasper Schmeichel   35           Leicester City
# 425     Neil Leonard Dula Etheridge   32             Cardiff City
# 478   Rui Pedro dos Santos Patrício   34  Wolverhampton Wanderers
# 84                       Bernd Leno   30                  Arsenal
# 145                    David de Gea   31        Manchester United
# 569                Łukasz Fabiański   37          West Ham United
# 542                  Vicente Guaita   35           Crystal Palace
# ...

# %%
data.sort_values(by='cards_per_90_overall', ascending=False).loc[(data['minutes_played_overall'] > 270)]
# Out:
#                   full_name  age   birthday birthday_GMT          league  \
# 514  Stefan Marius Johansen   31  663321600   1991/01/08  Premier League
# 44          Andreas Pereira   26  820483200   1996/01/01  Premier League
# 322          Kevin McDonald   33  594633600   1988/11/04  Premier League
# 466            Robbie Brady   30  695376000   1992/01/14  Premier League
# 448           Phil Jagielka   40  398415600   1982/08/17  Premier League
# ..                      ...  ...        ...          ...             ...
# 208         Gonzalo Higuain   34  566121600   1987/12/10  Premier League
# 415         Naby Deco Keïta   27  792403200   1995/02/10  Premier League
# 200       Gaëtan Bong Songo   34  577954800   1988/04/25  Premier League
# 423  Nathaniel Mendez-Laing   30  703321200   1992/04/15  Premier League
# 569        Łukasz Fabiański   37  482659200   1985/04/18  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# ...

# %%
data['nationality'].value_counts()
# Out:
# England                215
# Spain                   35
# France                  31
# Belgium                 20
# Republic of Ireland     20
#                       ...
# Israel                   1
# Montenegro               1
# Ecuador                  1
# Iran                     1
# Kenya                    1
# Name: nationality, Length: 67, dtype: int64

# %%
data.groupby(by='nationality')['age'].describe()
# Out:
#              count       mean       std   min    25%   50%    75%   max
# nationality
# Algeria        2.0  30.500000  0.707107  30.0  30.25  30.5  30.75  31.0
# Argentina     16.0  32.750000  4.654747  24.0  30.00  32.5  34.25  43.0
# Armenia        1.0  33.000000       NaN  33.0  33.00  33.0  33.00  33.0
# Australia      2.0  30.500000  0.707107  30.0  30.25  30.5  30.75  31.0
# Austria        4.0  34.750000  1.258306  33.0  34.50  35.0  35.25  36.0
# ...            ...        ...       ...   ...    ...   ...    ...   ...
# USA            5.0  29.200000  4.324350  24.0  26.00  29.0  33.00  34.0
# Ukraine        2.0  28.500000  4.949747  25.0  26.75  28.5  30.25  32.0
# Uruguay        2.0  31.500000  7.778175  26.0  28.75  31.5  34.25  37.0
# Venezuela      2.0  28.500000  4.949747  25.0  26.75  28.5  30.25  32.0
# Wales          9.0  29.222222  3.993050  22.0  29.00  30.0  31.00  35.0
#
# [67 rows x 8 columns]
